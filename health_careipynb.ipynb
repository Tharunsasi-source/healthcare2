# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/healthcare_dataset.csv")
df
# Out:
#     Patient_ID  Gender  Age Medical_Condition Admission_Date Admission_Type  \
# 0        P1001    Male   45      Hypertension     15-01-2026         Urgent
# 1        P1002  Female   32         Pneumonia     16-01-2026      Emergency
# 2        P1003    Male   68   Diabetes Type 2     16-01-2026        Routine
# 3        P1004  Female   55            Asthma     17-01-2026      Emergency
# 4        P1005    Male   29          Fracture     17-01-2026         Urgent
# ..         ...     ...  ...               ...            ...            ...
# 495      P1496  Female   50              COPD     20-09-2026      Emergency
# 496      P1497    Male   28          Fracture     20-09-2026         Urgent
# 497      P1498  Female   67      Heart Attack     21-09-2026      Emergency
# 498      P1499    Male   43   Diabetes Type 2     21-09-2026        Routine
# 499      P1500  Female   61            Stroke     22-09-2026      Emergency
#
#     Medical_Code  Billing_Amount Discharge_Date
# ...

# %%
df.head()
# Out:
#   Patient_ID  Gender  Age Medical_Condition Admission_Date Admission_Type  \
# 0      P1001    Male   45      Hypertension     15-01-2026         Urgent
# 1      P1002  Female   32         Pneumonia     16-01-2026      Emergency
# 2      P1003    Male   68   Diabetes Type 2     16-01-2026        Routine
# 3      P1004  Female   55            Asthma     17-01-2026      Emergency
# 4      P1005    Male   29          Fracture     17-01-2026         Urgent
#
#   Medical_Code  Billing_Amount Discharge_Date
# 0   ICD-10-I10          4500.0     20-01-2026
# 1   ICD-10-J18          6700.5     22-01-2026
# 2   ICD-10-E11          3200.0     18-01-2026
# 3   ICD-10-J45          5800.0     19-01-2026
# 4   ICD-10-S52          8500.0     25-01-2026

# %%
print(df.shape)
# Out:
# (500, 9)

# %%
print(df.describe())
# Out:
#               Age  Billing_Amount
# count  500.000000       500.00000
# mean    50.106000      7249.00100
# std     15.328035      3198.96932
# min     22.000000      2300.00000
# 25%     37.000000      4400.00000
# 50%     50.000000      6950.00000
# 75%     63.000000      9400.00000
# max     78.000000     14200.00000

# %%
print(df.isnull().sum())
# Out:
# Patient_ID           0
# Gender               0
# Age                  0
# Medical_Condition    0
# Admission_Date       0
# Admission_Type       0
# Medical_Code         0
# Billing_Amount       0
# Discharge_Date       0
# dtype: int64

# %%
df = df.dropna()

# %%
df["Admission_Date"] = pd.to_datetime(df["Admission_Date"], utc=True, dayfirst=True)
df['Admission_Date'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df["Discharge_Date"] = pd.to_datetime(df["Discharge_Date"], utc=True, dayfirst=True)
df['Discharge_Date'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df['Admission_Type'] = df['Admission_Type'].str.strip().str.lower()
df.head()
# Out:
#   Patient_ID  Gender  Age Medical_Condition            Admission_Date  \
# 0      P1001    Male   45      Hypertension 2026-01-15 00:00:00+00:00
# 1      P1002  Female   32         Pneumonia 2026-01-16 00:00:00+00:00
# 2      P1003    Male   68   Diabetes Type 2 2026-01-16 00:00:00+00:00
# 3      P1004  Female   55            Asthma 2026-01-17 00:00:00+00:00
# 4      P1005    Male   29          Fracture 2026-01-17 00:00:00+00:00
#
#   Admission_Type Medical_Code  Billing_Amount            Discharge_Date
# 0         urgent   ICD-10-I10          4500.0 2026-01-20 00:00:00+00:00
# 1      emergency   ICD-10-J18          6700.5 2026-01-22 00:00:00+00:00
# 2        routine   ICD-10-E11          3200.0 2026-01-18 00:00:00+00:00
# 3      emergency   ICD-10-J45          5800.0 2026-01-19 00:00:00+00:00
# 4         urgent   ICD-10-S52          8500.0 2026-01-25 00:00:00+00:00

# %%
df["Hospital_Stays"] = df["Discharge_Date"] - df["Admission_Date"]
df
# Out:
#     Patient_ID  Gender  Age Medical_Condition            Admission_Date  \
# 0        P1001    Male   45      Hypertension 2026-01-15 00:00:00+00:00
# 1        P1002  Female   32         Pneumonia 2026-01-16 00:00:00+00:00
# 2        P1003    Male   68   Diabetes Type 2 2026-01-16 00:00:00+00:00
# 3        P1004  Female   55            Asthma 2026-01-17 00:00:00+00:00
# 4        P1005    Male   29          Fracture 2026-01-17 00:00:00+00:00
# ..         ...     ...  ...               ...                       ...
# 495      P1496  Female   50              COPD 2026-09-20 00:00:00+00:00
# 496      P1497    Male   28          Fracture 2026-09-20 00:00:00+00:00
# 497      P1498  Female   67      Heart Attack 2026-09-21 00:00:00+00:00
# 498      P1499    Male   43   Diabetes Type 2 2026-09-21 00:00:00+00:00
# 499      P1500  Female   61            Stroke 2026-09-22 00:00:00+00:00
#
#     Admission_Type Medical_Code  Billing_Amount            Discharge_Date  \
# ...

# %%
df['Hospital_Stays'] = df['Hospital_Stays'].dt.days
Hospital_Stays_Summary = df['Hospital_Stays'].describe()
print(Hospital_Stays_Summary)
# Out:
# count    500.00000
# mean       2.74400
# std        1.17696
# min        1.00000
# 25%        2.00000
# 50%        2.00000
# 75%        4.00000
# max       10.00000
# Name: Hospital_Stays, dtype: float64

# %%
Billing_Amount_Summary = df['Billing_Amount'].describe()
print(Billing_Amount_Summary)
# Out:
# count      500.00000
# mean      7249.00100
# std       3198.96932
# min       2300.00000
# 25%       4400.00000
# 50%       6950.00000
# 75%       9400.00000
# max      14200.00000
# Name: Billing_Amount, dtype: float64

# %%
medical_condition_counts = df['Medical_Condition'].value_counts()
print(medical_condition_counts)
# Out:
# Medical_Condition
# COPD                       34
# Appendicitis               33
# Stroke                     33
# Pneumonia                  31
# Heart Failure              30
# Kidney Stone               28
# Hypertension               28
# Heart Attack               27
# Fracture                   22
# Gastritis                  21
# Skin Infection             20
# Back Pain                  20
# Asthma                     19
# Parkinson's Disease        19
# Urinary Tract Infection    18
# Pregnancy                  16
# Diabetes Type 2            16
# Allergic Reaction          15
# Gallstones                 15
# Diabetes Type 1            15
# Osteoporosis               12
# Osteoarthritis             12
# Anxiety Disorder            9
# Migraine                    6
# Hypothyroidism              1
# Name: count, dtype: int64

# %%
medical_condition_gender_crosstab = pd.crosstab(df['Medical_Condition'], df['Gender'])
print(medical_condition_gender_crosstab)
# Out:
# Gender                   Female  Male
# Medical_Condition
# Allergic Reaction            14     1
# Anxiety Disorder              2     7
# Appendicitis                  8    25
# Asthma                        8    11
# Back Pain                     5    15
# COPD                         16    18
# Diabetes Type 1              12     3
# Diabetes Type 2               6    10
# Fracture                      7    15
# Gallstones                    3    12
# Gastritis                    11    10
# Heart Attack                 15    12
# Heart Failure                10    20
# Hypertension                 19     9
# Hypothyroidism                1     0
# Kidney Stone                 10    18
# Migraine                      6     0
# Osteoarthritis                6     6
# Osteoporosis                  8     4
# Parkinson's Disease           9    10
# Pneumonia                    18    13
# Pregnancy                    14     2
# Skin Infection               12     8
# ...
